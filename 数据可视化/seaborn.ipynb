# %% [markdown]
# # python数据可视化——seaborn库介绍与使用
#
# Seaborn是基于Matplotlib的Python数据可视化库。它提供了一个高级界面，用于绘制引人入胜且内容丰富的统计图形
# 只是在Matplotlib上进行了更高级的API封装，从而使作图更加容易
# seaborn是针对统计绘图的，能满足数据分析90%的绘图需求，需要复杂的自定义图形还需要使用到Matplotlib
#
# seaborn 网站：http://seaborn.pydata.org/
# 可以自己去浏览学习
#
# 安装：在cmd中运行pip install seaborn
# 调用：import seaborn as sns

# %%
import seaborn

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.9.0'

# %%
#准备工作
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import pandas as pd

plt.rcParams['font.family']='SimHei'#'SimHei'为黑体
plt.rcParams['axes.unicode_minus'] = False #显示负号
sns.set_style('darkgrid',{'font.sans-serif':['SimHei','Arial']})

import warnings  # 去除部分警告信息
warnings.filterwarnings('ignore')

# %%
names = sns.get_dataset_names()
for i in names:
    sns.load_dataset(i)

# %% [markdown]
# # 柱状图

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy as np
import pandas as pd

sns.set()
plt.bar([1,2,3,4,5],[1,3,1,5,6])
# Out:
# <BarContainer object of 5 artists>

# %%
sns.set(style = 'whitegrid')  #darkgrid，whitegrid，dark, white, ticks
plt.bar([1,2,3,4,5],[1,3,1,5,6])
# Out:
# <BarContainer object of 5 artists>

# %%
sns.set(style = 'white')  #darkgrid，whitegrid，dark, white, ticks
plt.bar([1,2,3,4,5],[1,3,1,5,6])
sns.despine(
    left = True,
    bottom = True
)  # 去除图脊，默认上边和右边
#sns.despine()  # 去除图脊，默认上边和右边

# %%
plt.rcParams['font.family']='SimHei'#'SimHei'为黑体
plt.rcParams['axes.unicode_minus'] = False #显示负号

sns.set_style = 'whitegrid'#darkgrid，whitegrid，dark, white, ticks
plt.bar([1,2,3,4,5],[1,3,1,5,6])
sns.despine(
    left = True,
    bottom = True
)  # 去除图脊，默认上边和右边

plt.xticks([])
plt.yticks([1,2])
plt.title("柱状图")
# Out:
# Text(0.5,1,'柱状图')

# %%
#sns.set_style('darkgrid',{'font.sans-serif':['SimHei','Arial']})
plt.bar([1,2,3,4,5],[1,3,1,5,6])
plt.title("柱状图")

# %%
plt.rcParams['font.family']='SimHei'#'SimHei'为黑体
plt.rcParams['axes.unicode_minus'] = False #显示负号

sns.set_context("notebook")# paper, notebook, talk, poster
plt.bar([1,2,3,4,5],[1,3,1,5,6])
plt.title("柱状图")
# Out:
# Text(0.5,1,'柱状图')

# %%
help(sns.set_context)
# Out:
# Help on function set_context in module seaborn.rcmod:
#
# set_context(context=None, font_scale=1, rc=None)
#     Set the plotting context parameters.
#
#     This affects things like the size of the labels, lines, and other
#     elements of the plot, but not the overall style. The base context
#     is "notebook", and the other contexts are "paper", "talk", and "poster",
#     which are version of the notebook parameters scaled by .8, 1.3, and 1.6,
#     respectively.
#
#     Parameters
#     ----------
#     context : dict, None, or one of {paper, notebook, talk, poster}
#         A dictionary of parameters or the name of a preconfigured set.
#     font_scale : float, optional
#         Separate scaling factor to independently scale the size of the
#         font elements.
#     rc : dict, optional
#         Parameter mappings to override the values in the preset seaborn
#         context dictionaries. This only updates parameters that are
# ...

# %% [markdown]
# # seaborn 调色板
# - 连续渐变色板
# - 离散分类色板
# color_palette() 能传入任何Matplotlib所支持的颜色，不写参数时默认颜色
# set_palette()设置所有图的颜色
#
# 6个颜色主题：
# deep，muted, pastel, dark, colorblind

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %%
sns.barplot([1,2,3],[4,5,6],[7,8,9])

# %%
#deep，muted, pastel, dark, colorblind
sns.palplot(sns.color_palette("colorblind"))

# %%
colors = ['red','orange','yellow','g','b','purple']
#print(sns.color_palette(colors))
sns.palplot(sns.color_palette(colors))

# %%
sns.palplot(sns.color_palette('Blues'))

# %%
sns.palplot(sns.color_palette('Accent'))  # YlGn, hls
sns.palplot(sns.color_palette('Accent_r',10))
sns.palplot(sns.color_palette('YlGn'))  
sns.palplot(sns.color_palette('YlGn_r'))

# %%
#彩虹色
sns.palplot(sns.color_palette('hls'))

sns.palplot(sns.hls_palette(15,l = 0.7, s = 0.9))

# %%
sns.barplot([1,2,3],[4,5,6],[7,8,9],palette = sns.color_palette('YlGn'))

# %%
sns.barplot([1,2,3],[4,5,6],[7,8,9])

# %%
co = sns.choose_cubehelix_palette(as_cmap = True)
# Out:
# A Jupyter Widget

# %% [markdown]
# # 调色板：https://seaborn.pydata.org/tutorial/color_plattes.html
# # sns.set()  #返回默认设置

# %%
x = ['金融','农业','制造业','新能源']
y = [164, 56, 126, 58]
sns.barplot(y,x                                          #要想横过来把x,y反过来
            ,order = ['金融','制造业','农业','新能源']   #更改位置                          
            #,seturation = 0.25
           )

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips = sns.load_dataset("tips")
tips.head()
tips = sns.barplot(x = 'day', y = 'tip'  #竖线是误差线，柱子的高度是那一类别下的均值（置信区间）
                   ,data = tips
                   ,hue = 'sex'
                   ,palette = 'Purples'
                  )

# %% [markdown]
# # 条形图 交换x,y

# %%
sns.barplot(y = 'day',x = 'tip', data = tips)

# %% [markdown]
# # 箱线图 boxplot

# %%
L = [9,3,1,5,3]
sns.boxplot(y = L)  #竖向
# sns.boxplot(L)    #横向

# %%
tips = sns.load_dataset("tips")   #导入数据集在seaborn库的介绍与使用中有讲解
tips.head()
sns.boxplot(x = 'day',y = 'tip'   #x,y交换位置箱线图 横向     
            ,data = tips
            ,hue = 'sex'          # 按照性别分类
            ,palette = 'Purples'  # 设置颜色调色盘
           )

# %% [markdown]
# # 小提琴图（箱线图和密度图的结合）

# %%
L = [9,3,1,5,3]
sns.violinplot(y = L)  # x = L 可以将小提琴图横过来

# %%
sns.violinplot(x = 'day',y = 'tip'
               ,data = tips
               ,hue = 'sex'
               ,split = True  # 从中间切一半
               #,scale_hue
               #,inner
              )

# %% [markdown]
# # 分类散点图 strip(带状), swarm(蜂群图)

# %%
sns.stripplot(x = 'day',y = 'tip'
              ,data = tips
              ,hue = 'sex'        # 以性别分类
              ,palette = 'Blues'  # 设置颜色调色盘
              ,dodge = True      # 分开显示
             )

# %%
help(sns.stripplot)
# Out:
# Help on function stripplot in module seaborn.categorical:
#
# stripplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, jitter=True, dodge=False, orient=None, color=None, palette=None, size=5, edgecolor='gray', linewidth=0, ax=None, **kwargs)
#     Draw a scatterplot where one variable is categorical.
#
#     A strip plot can be drawn on its own, but it is also a good complement
#     to a box or violin plot in cases where you want to show all observations
#     along with some representation of the underlying distribution.
#
#
#     Input data can be passed in a variety of formats, including:
#
#     - Vectors of data represented as lists, numpy arrays, or pandas Series
#       objects passed directly to the ``x``, ``y``, and/or ``hue`` parameters.
#     - A "long-form" DataFrame, in which case the ``x``, ``y``, and ``hue``
#       variables will determine how the data are plotted.
#     - A "wide-form" DataFrame, such that each numeric column will be plotted.
# ...

# %%
sns.swarmplot(x = 'day',y = 'tip'
              ,data = tips
              ,hue = 'sex'          # 以性别分类 
              ,palette = 'icefire'  # 设置颜色调色盘
             )

# %% [markdown]
# # 分面网格分类图 facegrid
# ## 绘制子图，不同图之间有联系
# ## 绘制分类图 catplot（col_wrap:在x轴上绘制子图的最大个数，kind：绘制子图类型[‘bar’,'strip','swarm'...]）

# %%
sns.catplot(x = 'day',y = 'tip',data = tips
            #,hue = 'sex'
            #,col = 'time' # 'size'
            #,col_wrap = a    #限制每行放a个图
            #,kind = 'violin'
            #,split = True
            #,row = 'smoker'
           )

# %% [markdown]
# # 散点图 scatterplot(x,y,hue,size,style)

# %%
sns.scatterplot(x = 'day',y = 'tip',data = tips)

# %% [markdown]
# # 线图
# seaborn.lineplot(x, y, hue, style, size, data)
# 如果data设定，则其余参数取值是data中列名
# ## hue是分类变量
# # 保证每一列都是数值型数据

# %%
data = {
    'apples':[3,2,0,1],
    'oranges':[0,1,2,3],
    'bananas':[1,2,1,0]
}
df = pd.DataFrame(data,index = ['June','Robert','Lily','David'])
sns.lineplot(data=df) #保证每一列都是数值型数据

# %%
file_path = r'D:\用户目录\我的文档\Tencent Files\1521131720\FileRecv\data_pandas(20191021)'
df20 = pd.read_excel(file_path + '\全国总人口数据.xls',sheet_name = '20年数据',skiprows = 2,skipfooter = 2)
plt.figure(figsize = (15,6))
ax = sns.lineplot(data = df20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# E:\Anaconda3\lib\site-packages\seaborn\relational.py in establish_variables(self, x, y, hue, size, style, units, data)
#      60                 try:
# ---> 61                     data.astype(np.float)
#      62                 except ValueError:
#
# E:\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#
# E:\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#
# ...

# %%
tips = sns.load_dataset('tips')
tips.head()
plt.figure(dpi = 150)
sns.lineplot(x = 'total_bill',
             y = 'tip',
             hue = 'sex',
             size = 'smoker',
             style = 'time',
             data = tips,
            )

# %% [markdown]
# # 分面网格关联图
# relplot()  反映数值型的关系
# ## 默认画散点图

# %%
mpg_df = sns.load_dataset('mpg')

# %%
g = sns.relplot(x = 'displacement',y = 'mpg',
               col = 'cylinders', #竖向划分(分列)
               col_wrap = 2,      #一行画2个图
               hue = 'origin',    #横向划分（分行）
               kind = 'line',     #可以画什么样的图
               data = mpg_df)

# %% [markdown]
# # dist图 直方图
# sns.distplot(a,
#             bins, #直方图中柱体个数
#             hist, #是否绘制直方图
#             kde   #密度
#             )

# %%
sns.distplot(tips['total_bill'],
            #shape = True,
            #bw = 6
           )

# %% [markdown]
# # kde 密度图
# 双变量图 等高线图
# sns.kdeplot()

# %%
n = 1024
x = np.random.normal(0,1,n)
y = np.random.normal(0,1,n)
g = sns.kdeplot(x,y,kind = 'kde')

# %% [markdown]
# # 连接图 joinplot

# %%
n = 1024
x = np.random.normal(0,1,n)
y = np.random.normal(0,1,n)
g = sns.jointplot(x,y,
                kind = 'reg' #回归线 ‘kde’'hex'
                )

# %% [markdown]
# # 热力图
# heatmap(data,vmin,cmap,)

# %%
df = pd.DataFrame(np.random.rand(6,6),columns = list('abcdef'))
sns.heatmap(df,
            cmap = 'YlGn',#设置颜色面板
            annot = True  #标上数值
           )

# %% [markdown]
# # 线性回归
# regplot

# %%
df = sns.load_dataset('tips')
sns.regplot(x = 'total_bill',y = 'tip',data = df)

# %% [markdown]
# # 分面网格回归
# Implot
# # 分类

# %%
df = sns.load_dataset('tips')
g = sns.lmplot(data = df, x = 'x',y = 'y',hue = 'cat1',col = 'cat2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-b81a89da07db> in <module>
#       1 df = sns.load_dataset('tips')
# ----> 2 g = sns.lmplot(data = df, x = 'x',y = 'y',hue = 'cat1',col = 'cat2')
#
# E:\Anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     549     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     550     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 551     data = data[cols]
#     552
#     553     # Initialize the grid
#
# ...

# %% [markdown]
# # 分面网格绘图
# - sns.FaceGrid(data, row, col, hue, col_warp)
# - Facegrid.map()

# %%
mpg_df = sns.load_dataset('mpg')
g = sns.FacetGrid(mpg_df,col = 'origin')
g.map(sns.distplot,'mpg')

# %% [markdown]
# # 分类散点图

# %%
stripplot
